# %% [markdown]
# ### **`Problem-1:`** Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# **Exercise 1:**
#
# Input:
#
# ```bash
# [1,2,3,3,3,3,4,5]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5]
# ```

# %%
def unique_list(numbers):
  return list(set(numbers))

number = [1, 2, 3, 3, 3, 3, 4, 5]
print(unique_list(number))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **`Problem-2:`** Write a Python function that accepts a hyphen-separated sequence of words as parameter and returns the words in a hyphen-separated sequence after sorting them alphabetically.
#
# **Example 1:**
#
# Input:
# ```bash
# green-red-yellow-black-white
# ```
#
# Output:
# ```bash
# black-green-red-white-yellow
# ```

# %%
def sort_words(sequence):
  return "-".join(sorted(sequence.split('-')))

input_str = "green-red-yellow-black-white"
print(sort_words(input_str))
# Out:
# black-green-red-white-yellow

# %% [markdown]
# ### **`Problem 3:`** Write a Python function that accepts a string and calculate the number of upper case letters and lower case letters.
#
# ```
# Sample String : 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
# Expected Output :
# No. of Upper case characters :  9
# No. of Lower case Characters :  47
# ```

# %%
def count_case(s):
    upper = 0
    lower = 0

    for char in s:
        if char.isupper():
            upper += 1
        if char.islower():
            lower += 1

    print("No. of Upper case characters :", upper)
    print("No. of Lower case Characters :", lower)

# Test Input
sample_string = 'CampusX is an online Mentorship Program for EnginEering students.'
count_case(sample_string)
# Out:
# No. of Upper case characters : 6
# No. of Lower case Characters : 50

# %% [markdown]
# ### **`Problem 4:`** Write a Python program to print the even numbers from a given list.
# ```
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]
# ```

# %%
def get_even_numbers(lst):
  even_list = []
  for num in lst:
      if num % 2 == 0:
          even_list.append(num)
  return even_list

sample_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(get_even_numbers(sample_list))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ### **`Problem 5:`** Write a Python function to check whether a number is perfect or not.
#
# A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# Example :
#
# ```
# The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.
# ```

# %%
def is_perfect(num):
    total = 0

    # 1 se lekar num-1 tak sabhi divisors check karenge
    for i in range(1, num):
        if num % i == 0:
            total += i

    # Agar divisors ka sum number ke barabar hai, toh True
    return total == num

# Test Call
print(is_perfect(6))
# Out:
# True

# %% [markdown]
# ### **`Problem-6:`** Write a Python function to concatenate any no of dictionaries to create a new one.
#
# ```
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```

# %%
def concat_dicts(*args):
  res = {}
  for d in args:
    res.update(d)
  return res

dic1 = {1: 10, 2: 20}
dic2 = {3: 30, 4: 40}
dic3 = {5: 50, 6: 60}
print(concat_dicts(dic1, dic2, dic3))
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# `Problem-7` Write a python function that accepts a string as input and returns the word with most occurence.
#
# ```
# Input:
# hello how are you i am fine thank you
# ```
#
# ```
# Output
# you -> 2
# ```

# %%
def most_frequent_word(text):
    words = text.split()

    # Highest count wala word find karenge
    best_word = words[0]

    for w in words:
        if words.count(w) > words.count(best_word):
            best_word = w

    print(f"{best_word} -> {words.count(best_word)}")

# Test Input
s = "hello how are you i am fine thank you"
most_frequent_word(s)
# Out:
# you -> 2

# %% [markdown]
# `Problem-8` Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# ```
# Input:
# [13,42,15,37,22,39,41,50]
# ```
#
# ```
# Output:
# {11-20:2,21-30:1,31-40:2,41-50:3}
# ```

# %%
def print_histogram(numbers):
    histogram = {}

    for num in numbers:
        # Range nikalne ka logic (e.g., 13 -> 11-20, 22 -> 21-30)
        start = ((num - 1) // 10) * 10 + 1
        end = start + 9
        bin_range = f"{start}-{end}"

        # Count badhane ka logic
        histogram[bin_range] = histogram.get(bin_range, 0) + 1

    print(histogram)

# Test Input
nums = [13, 42, 15, 37, 22, 39, 41, 50]
print_histogram(nums)
# Out:
# {'11-20': 2, '41-50': 3, '31-40': 2, '21-30': 1}

# %% [markdown]
# `Problem-9` Write a python function that accepts a list of 2D co-ordinates and a query point, and then finds the the co-ordinate which is closest in terms of distance from the query point.
#
# ```
# List of Coordinates
# [(1,1),(2,2),(3,3),(4,4)]
# Query Point
# (0,0)
# ```
#
# ```
# Output
# Nearest to (0,0) is (1,1)
# ```

# %%
def find_closest(points, query):
    closest_point = points[0]
    min_dist = float('inf')

    qx, qy = query

    for point in points:
        px, py = point
        # Distance formula: (x2 - x1)**2 + (y2 - y1)**2
        dist = (px - qx)**2 + (py - qy)**2

        if dist < min_dist:
            min_dist = dist
            closest_point = point

    print(f"Nearest to {query} is {closest_point}")

# Test Input
coords = [(1,1), (2,2), (3,3), (4,4)]
q_point = (0,0)

find_closest(coords, q_point)
# Out:
# Nearest to (0, 0) is (1, 1)

# %% [markdown]
# ###`Problem 11:` Write a Python program to add three given lists using Python map and lambda.

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 5]
list3 = [7, 8, 9]

result = list(map(lambda x, y, z: x + y + z, list1, list2, list3))

print(result)
# Out:
# [12, 15, 17]

# %% [markdown]
# ###`Problem-12:`Write a Python program to create a list containing the power of said number in bases raised to the corresponding number in the index using Python map.
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,2,9,64,625,-]
# ```

# %%
list1 = [1,2,3,4,5,6]
list(map(lambda x,y:x**y,list1,range((len(list1)))))
# Out:
# [1, 2, 9, 64, 625, 7776]

# %% [markdown]
# ###`Problem-13` Using filter() and list() functions and .lower() method filter all the vowels in a given string.

# %%
s = "Hello World"

vowels = list(filter(lambda char: char.lower() in 'aeiou', s))
print(vowels)
# Out:
# ['e', 'o', 'o']

# %% [markdown]
# `Problem-14`: Use reduce to convert a 2D list to 1D

# %%
from functools import reduce
matrix = [[1, 2, 3], [4, 5], [6, 7, 8]]

flat_list = reduce(lambda x, y: x + y, matrix)

print(flat_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# `Problem 15`- A dictionary contains following information about 5 employees:
# - First name
# - Last name
# - Age
# - Grade(Skilled,Semi-skilled,Highly skilled)<br>
# Write a program using map/filter/reduce to a list of employees(first name + last name) who are highly skilled

# %%
# Sample 5 employees ka data (List of Dictionaries)
employees = [
    {"fname": "Rahul", "lname": "Sharma", "age": 28, "grade": "Highly skilled"},
    {"fname": "Amit", "lname": "Verma", "age": 32, "grade": "Skilled"},
    {"fname": "Priya", "lname": "Singh", "age": 25, "grade": "Highly skilled"},
    {"fname": "Neha", "lname": "Gupta", "age": 30, "grade": "Semi-skilled"},
    {"fname": "Vikas", "lname": "Kumar", "age": 29, "grade": "Highly skilled"}
]

# Step 1: Sirf 'Highly skilled' employees ko filter karo
highly_skilled = filter(lambda emp: emp['grade'] == 'Highly skilled', employees)

# Step 2: Unke First name + Last name ko join karke list banao
result = list(map(lambda emp: emp['fname'] + " " + emp['lname'], highly_skilled))

print(result)
# Out:
# ['Rahul Sharma', 'Priya Singh', 'Vikas Kumar']
