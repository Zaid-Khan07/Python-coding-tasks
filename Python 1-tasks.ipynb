# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# write your code here
print("zaid", "khan", "india", sep="-", end="!")
# Out:
# zaid-khan-india!

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
celsius = float(input("Enter temperature in celsius:"))

fahrenheit = (celsius * 9/5) + 32

print(celsius, "°C =", fahrenheit, "°F")
# Out:
# Enter temperature in celsius:50
# 50.0 °C = 122.0 °F

# %%
fahrenheit = float(input("Enter temperature in fahrenheit:"))

celsius = (fahrenheit - 32) * 9/5

print(fahrenheit, "°F", celsius, "°C")
# Out:
# Enter temperature in fahrenheit:34
# 34.0 °F 3.6 °C

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# write your code here
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

print("Before Swap: a=", a, "b=", b)

# Swapping without temp variable
a = a + b
b = a - b
a = a - b

print("After Swap: a=", a, "b =", b)
# Out:
# Enter first number:45
# Enter second number:54
# Before Swap: a= 45 b= 54
# After Swap: a= 54 b = 45

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
x1 = float(input("Enter x1:"))
y1 = float(input("Enter y1:"))

x2 = float(input("Enter x2:"))
y2 = float(input("Enter y2:"))

distance = ((x2 - x1)**2 + (y2 - y1)**2) ** 0.5

print("Euclidean Distance =", distance)
# Out:
# Enter x1:1
# Enter y1:2
# Enter x2:3
# Enter y2:4
# Euclidean Distance = 2.8284271247461903

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
p = float(input("Enter principle:"))
r = float(input("Enter rate of interst (in %): "))
t = float(input("Enter time period (in month): "))

si = (p*r*t) / 100

print("Simple Interest =", si)
# Out:
# Enter principle:1
# Enter rate of interst (in %): 45
# Enter time period (in month): 50
# Simple Interest = 22.5

# %%
heads = input("Enter heads:")
Legs = input("Enter legs:")
